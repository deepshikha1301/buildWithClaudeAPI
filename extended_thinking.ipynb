# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type":"enabled",
            "budget_tokens":thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write one paragraph guide to recursion.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CepRYbxSFuvmzFUp2zXSe', container=None, content=[ThinkingBlock(signature='...', thinking="I need to write a clear, concise paragraph that explains recursion. I should cover:\n- What it is\n- How it works\n- Key components (base case, recursive case)\n- Maybe a simple example or analogy\n- Keep it accessible but informative\n\nLet me aim for something that's helpful for someone trying to understand the concept.", type='thinking'), TextBlock(citations=None, text="# Understanding Recursion\n\nRecursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. Every recursive function needs two essential components: a **base case** that stops the recursion and returns a direct answer, and a **recursive case** that calls the function again with modified parameters, moving closer to the base case. Think of it like a set of Russian nesting dolls—you open one doll to find a smaller version inside, repeating until you reach the smallest doll that can't be opened further (the base case). For example, calculating factorial(5) recursively means computing 5 × factorial(4), which needs 4 × factorial(3), and so on, until you hit factorial(1) = 1 (base case), then all the results multiply back up the chain. While recursion can make certain problems (like tree traversal, divide-and-conquer algorithms, or mathematical sequences) more elegant and intuitive than iterative solutions, it's important to ensure your base case is reachable and be mindful of stack overflow errors with deep recursion.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=44, output_tokens=330, output_tokens_details=OutputTokensDetails(thinking_tokens=79), server_tool_use=None, service_tier='standard'))

# %%
#Redacted Thinking
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CepRxToiGF3xY7Xxxam4W', container=None, content=[RedactedThinkingBlock(data='...', type='redacted_thinking'), TextBlock(citations=None, text="I'm Claude, an AI assistant made by Anthropic. I don't have any special response to that string of characters. Is there something I can help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=95, output_tokens_details=OutputTokensDetails(thinking_tokens=53), server_tool_use=None, service_tier='standard'))
